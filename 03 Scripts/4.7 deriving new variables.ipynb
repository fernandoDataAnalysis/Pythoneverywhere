# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## importing data

# %%
path = r"C:\Users\siram\OneDrive\Desktop\Instacart Basket Analysis"

# %%
df_orders_products_merged = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged.pkl'))

# %%
df_orders_products_merged=df_orders_products_merged[:1000000]

# %% [markdown]
# # creating price_range column

# %%
df = df_orders_products_merged

# %%
df.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  order_dow  \
# 0             19     5.8   3139998      138    prior            28          6
# 1             19     5.8   1977647      138    prior            30          6
# 2             19     5.8    389851      709    prior             2          0
# 3             19     5.8    652770      764    prior             1          3
# 4             19     5.8   1813452      764    prior             3          4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
df = df_orders_products_merged[:1000000]

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False )
# Out:
# Mid-range product    659373
# Low-range product    331283
# High range             9344
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %%
df.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  order_dow  \
# 0             19     5.8   3139998      138    prior            28          6
# 1             19     5.8   1977647      138    prior            30          6
# 2             19     5.8    389851      709    prior             2          0
# 3             19     5.8    652770      764    prior             1          3
# 4             19     5.8   1813452      764    prior             3          4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %% [markdown]
# # creating a busiest_day column

# %%
df_orders_products_merged["order_dow"].value_counts(dropna = False)
# Out:
# 0    184034
# 1    174567
# 6    136739
# 2    132114
# 5    131867
# 3    120940
# 4    119739
# Name: order_dow, dtype: int64

# %%
result = []

for value in df_orders_products_merged["order_dow"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Busiest day',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Busiest day',
#  'Regularly busy',
#  'Busiest day',
#  'Least busy',
#  'Busiest day',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df['busiest_day'] = result

# %%
df.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  order_dow  \
# 0             19     5.8   3139998      138    prior            28          6
# 1             19     5.8   1977647      138    prior            30          6
# 2             19     5.8    389851      709    prior             2          0
# 3             19     5.8    652770      764    prior             1          3
# 4             19     5.8   1813452      764    prior             3          4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
df['busiest_day'].value_counts(dropna = False)
## IM working only with the first 1000000 rows
# Out:
# Regularly busy    696227
# Busiest day       184034
# Least busy        119739
# Name: busiest_day, dtype: int64

# %% [markdown]
# # busiest days and slowest days columns

# %%
result_2 = []

for value in df["order_dow"]:
  if value == 0:
    result_2.append("Busiest_days")
  elif value == 1:
    result_2.append("Busiest_days")
  elif value == 3:
    result_2.append("Slowest_days")
  elif value ==4:
    result_2.append("Slowest_days")
  else:
    result_2.append("Regularly busy")

# %%
result_2
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Slowest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Regularly busy',
#  'Slowest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
# ...

# %%
df['Busiest_day'] = new_result

# %%
df['Busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    400720
# Busiest_days      358601
# Slowest_days      240679
# Name: Busiest_day, dtype: int64

# %% [markdown]
# # busiest hours of the day

# %%
df['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    86399
# 11    84804
# 14    82985
# 13    82197
# 15    81121
# 12    80503
# 16    77638
# 9     77082
# 17    64025
# 8     53631
# 18    49977
# 19    38479
# 20    30380
# 7     27652
# 21    24383
# 22    19139
# 23    12126
# 6      9105
# 0      6540
# 1      3550
# 5      2847
# 2      2173
# 3      1639
# 4      1625
# Name: order_hour_of_day, dtype: int64

# %%
# 10 am is the busiest time of the day

# %% [markdown]
# # creating the column busiest_period_of_the_day

# %%
result_3 = []

for value in df["order_hour_of_day"]:
  if value > 10 & value <=18:
    result_3.append("Most_orders")
  elif value <=5:
    result_3.append("Fewest_orders")
  else:
    result_3.append("Average_orders")

# %%
result_3
# Out:
# ['Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Fewest_orders',
#  'Most_orders',
#  'Fewest_orders',
#  'Fewest_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
# ...

# %%
df['Busiest_period_of_day'] = result_3

# %%
df['Busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most_orders       851257
# Average_orders    140030
# Fewest_orders       8713
# Name: Busiest_period_of_day, dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  order_dow  \
# 0             19     5.8   3139998      138    prior            28          6
# 1             19     5.8   1977647      138    prior            30          6
# 2             19     5.8    389851      709    prior             2          0
# 3             19     5.8    652770      764    prior             1          3
# 4             19     5.8   1813452      764    prior             3          4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %% [markdown]
# # exporting the file

# %%
df_ords_prods_merge = df

# %%
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0  product_id                product_name  aisle_id  \
# 0           0           1  Chocolate Sandwich Cookies        61
# 1           0           1  Chocolate Sandwich Cookies        61
# 2           0           1  Chocolate Sandwich Cookies        61
# 3           0           1  Chocolate Sandwich Cookies        61
# 4           0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  order_id  user_id eval_set  order_number  order_dow  \
# 0             19     5.8   3139998      138    prior            28          6
# 1             19     5.8   1977647      138    prior            30          6
# 2             19     5.8    389851      709    prior             2          0
# 3             19     5.8    652770      764    prior             1          3
# 4             19     5.8   1813452      764    prior             3          4
#
#    order_hour_of_day  days_since_prior_order  add_to_cart_order  reordered  \
# ...

# %%
df_ords_prods_merge.to_pickle(os.path.join(path,'02 Data', 'Prepared Data', 'df_orders_products_merged.pkl'))
